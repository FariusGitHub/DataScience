# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/%E5%9C%A8%E5%AE%B6%E5%B7%A5%E4%BD%9C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 在家工作的数据科学家
#
# https://farius.s3.us-east-2.amazonaws.com/wcd/Farius_Tjioesman_Final_Project.pdf

# %%
# !pip install kora -q
from kora.selenium import wd
from selenium.webdriver.common.by import By
import time

prefix='/html/body/main/div/div/div/div[3]/div[2]/div'; 

wd.get("https://www.coursecompare.ca/courses/antigonish/weclouddata/data-science-bootcamp-8/")
more = int(wd.find_element(By.XPATH, "/html/body/header/div[2]/div/"\
                               "div[2]/div[2]/div/div/a").text.split(' ')[1])
load = int(more/2)

wd.find_element(By.XPATH, "/html/body/header/div[2]/div/div[2]/div[2]/"\
                "div/div/div").click(); time.sleep(1)
display(wd)

for i in range(load):
  wd.find_element(By.XPATH, prefix + "[4]/button").click(); time.sleep(1)

for i in range(more):     
    try: 
        if wd.find_element(By.XPATH,prefix + \
                  '['+str(i+2)+']/div[1]/div[1]/div[2]/div[1]/p/span')\
                  .text == 'Sales Engineer':
            wd.find_element(By.XPATH, prefix +\
                            "["+str(i+2)+"]/div[2]/button").click(); 
            wd.find_element(By.XPATH, prefix +\
                            "["+str(i+1)+"]/div[2]/div[1]/p").click();
            break
    except:
        continue

display(wd)
# Out:
#      |████████████████████████████████| 57 kB 1.9 MB/s
#      |████████████████████████████████| 55 kB 2.9 MB/s
# <selenium.webdriver.chrome.webdriver.WebDriver (session="8f555bcf420e32db51d6a718f307b484")>
# <selenium.webdriver.chrome.webdriver.WebDriver (session="8f555bcf420e32db51d6a718f307b484")>

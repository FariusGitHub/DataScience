# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/pmp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kora -q
from kora.selenium import wd
from selenium.webdriver.common.by import By
import time

prefix='/html/body/div[2]/div/div[3]/div[2]/div/div/div/div/div/div[2]/form/div'
wd.get("https://www.pmi.org/certifications/certification-resources/registry")
wd.find_element(By.XPATH, prefix+'[1]/input').send_keys('Farius');
wd.find_element(By.XPATH, prefix+'[4]/select').send_keys('ccc');
wd.find_element(By.XPATH, prefix+'[6]/input').click(); time.sleep(3)
display(wd)
wd.execute_script("window.scrollTo(0, 600)")
display(wd)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="cbe1af97eb10e35a894599acedca2adb")>
# <selenium.webdriver.chrome.webdriver.WebDriver (session="cbe1af97eb10e35a894599acedca2adb")>

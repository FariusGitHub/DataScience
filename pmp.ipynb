# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/pmp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 在家工作的数据科学家
#
# https://farius.s3.us-east-2.amazonaws.com/wcd/Farius_Tjioesman_Final_Project.pdf

# %%
# !pip install kora -q
from kora.selenium import wd
from selenium.webdriver.common.by import By
import time

wd.get("https://www.pmi.org/certifications/certification-resources/registry")
wd.find_element(By.XPATH, '/html/body/div[2]/div/div[3]/div[2]/div/div/div/div/div/div[2]/form/div[1]/input').send_keys('Farius');
wd.find_element(By.XPATH, '/html/body/div[2]/div/div[3]/div[2]/div/div/div/div/div/div[2]/form/div[4]/select').send_keys('ccc');
wd.find_element(By.XPATH, '/html/body/div[2]/div/div[3]/div[2]/div/div/div/div/div/div[2]/form/div[6]/input').click(); time.sleep(1)
wd.execute_script("window.scrollTo(0, 300)")
display(wd)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="48e52cd73b2dbbda4764b2e531ce0514")>

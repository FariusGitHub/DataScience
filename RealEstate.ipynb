# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/RealEstate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Mortgage Completion Machine Learning
#
# https://farius.s3.us-east-2.amazonaws.com/wcd/Farius_Tjioesman_ML.pdf

# %%
# !pip install kora -q
from kora.selenium import wd
from selenium.webdriver.common.by import By
import time

wd.get("https://careerkarma.com/schools/weclouddata/")
display(wd)
time.sleep(2)
# wd.find_element_by_xpath("/html/body/div[2]/div/div[2]/div/div[2]/button").click();
wd.find_element(By.XPATH, "/html/body/div/div/div/div[2]/div/div/div/div/div/div[1]/div[2]/div/div/div/a[3]").click(); time.sleep(1)
wd.find_element(By.XPATH, "/html/body/div/div/div/div[2]/div/div/div/div/div/div[2]/div[1]/div[1]/div/div/div/div[2]/div[7]/div[3]/div[1]/div[2]/label").click();
wd.find_element(By.XPATH, "/html/body/div/div/div/div[2]/div/div/div/div/div/div[2]/div[1]/div[1]/div/div/div/div[2]/div[7]/div[3]/div[2]/div[2]/label").click();
display(wd)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="c09bdb1ad6fb4f3363d20a554d95de2c")>
# <selenium.webdriver.chrome.webdriver.WebDriver (session="c09bdb1ad6fb4f3363d20a554d95de2c")>

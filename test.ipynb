# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#application of model deployment from joblib/cloudpickle technique
import joblib
joblib.load("test.pkl").fit_transform([i+1 for i in range(56+12)])

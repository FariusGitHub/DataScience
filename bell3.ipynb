# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/bell3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Improved Web Scraping at WeCloudData
# Farius Tjioesman - 21 October 2020
#
# ..

# %% [markdown]
# ![Picture1.jpg](attachment:ff824983-91f9-4de2-a619-5929e4dc1245.jpg)

# %% [markdown]
# ...

# %% [markdown]
# ![Picture2.jpg](attachment:247bc020-755d-4a81-b51c-4b89becb7717.jpg)

# %% [markdown]
# ...

# %%
import requests
import bs4          

import matplotlib.pyplot as plt
import matplotlib.image as img 

from tqdm.notebook import tqdm
import pandas as pd 

# BEAUTIFULSOUP/REQUEST LIBRARIES TO EXTRACT WHOLE HTML (SELENIUM NOT REQUIRED)
bell_url="https://www.bell.ca/Mobility/Smartphones_and_mobile_internet_devices"
soup = bs4.BeautifulSoup(requests.get(bell_url).text,"lxml")

# DICTIONARY COMPREHENSION, NESTED QUERY for picture/name (formerly dlist/glist)
dgdic={postpaid.get('alt') : "https://www.bell.ca/" + \
       str(postpaid.get('data-src')) for postpaid in soup \
       .select('.dl-tile-img') if 'Prepaid' not in postpaid }

# PANDA DATAFRAME intead of loop to get price from BeautifulSoup        
plist = pd.DataFrame(soup.select(".dl-tile-full-price")) 

# MATPLOTLIB, TQDM, LAMBDA FUNC. for data grouping, visualisation        
for summary in tqdm(range(len(plist))):
    im=img.imread(list(dgdic.values())[summary])
    plt.imshow(im); plt.axis('off'); plt.show()        
    print(list(dgdic.keys())[summary])
    print(plist[1].apply(lambda x: x.text.strip('\r\n '))[summary])
# Out:
# ...
# Samsung Galaxy S20 FE 5G
# $1,200.00
# Samsung Galaxy S20 Ultra 5G
# $2,300.00
# Samsung Galaxy S20+ 5G
# $2,000.00
# Samsung Galaxy S20 5G
# $1,650.00
# Samsung Galaxy Note20 Ultra 5G
# $2,250.00
# Samsung Galaxy Note20 5G
# $1,730.00
# Samsung Galaxy Z Fold2 5G
# $3,450.00
# Samsung Galaxy Z Flip 5G
# $2,500.00
# Samsung Galaxy Z Flip
# $1,819.99
# Samsung Galaxy S10+
# $1,574.99
# Samsung Galaxy S10
# $1,399.99
# Samsung Galaxy Note10+
# $1,699.99
# Samsung Galaxy A71
# $700.00
# Samsung Galaxy A51
# $560.00
# Samsung Galaxy A21
# $360.00
# Samsung Galaxy A11
# $250.00
# iPhone SE (2nd generation)
# $615.00
# iPhone 11
# $875.00
# iPhone XR
# $720.00
# iPhone 11 Pro
# $1,100.00
# ---------------------------------------------------------------------------
# IncompleteRead                            Traceback (most recent call last)
# <ipython-input-1-dc0abd75e406> in <module>
#      22 # MATPLOTLIB, TQDM, LAMBDA FUNC. for data grouping, visualisation
# ...

# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/cswp.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install kora -q
from kora.selenium import wd
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from tqdm import tqdm 

wd.get("https://3dexperience.virtualtester.com/")

time.sleep(2)
ht_pref = '/html/body/div[1]/div/div[2]/div/div/div'
element = wd.find_element(By.XPATH, ht_pref+'[1]/ul/li[5]')
wd.execute_script("arguments[0].click();", element)
time.sleep(1)

prefix = ht_pref + \
  '[2]/div[2]/div/div/div/div/div[1]/div/div/div[1]/div/div/div/div/div'

wd.find_element(By.XPATH, prefix + '[2]/div/div[2]/div[1]/input').\
  send_keys('Canada', Keys.ENTER)

for i in tqdm(range(4)):
  wd.find_element(By.XPATH, prefix + '[1]/div/div[2]/div[1]/input').click()
  wd.find_element(By.XPATH, prefix + '[1]/div/div[2]/div[1]/input').\
    send_keys(Keys.ARROW_DOWN)
  wd.find_element(By.XPATH, prefix + '[1]/div/div[2]/div[1]/input').\
    send_keys(Keys.ENTER)
  time.sleep(2)

url2 = prefix[:70]+'[2]/div/div/div/div/div[1]/div[2]/div[2]/div[1]'
url3 = prefix[:70]+'[2]/div/div/div/div/div[2]/div[2]/div/div/div/div[1]/div/div'

wd.find_element(By.XPATH, url2).click()

for i in tqdm(range(1480)):
  wd.find_element(By.XPATH, url2).send_keys(Keys.DOWN)

while wd.find_element(By.XPATH, url3).text.split(' ')[0] != 'Farius':
  wd.find_element(By.XPATH, url2).send_keys(Keys.DOWN)

time.sleep(2)
display(wd)
# Out:
#      |████████████████████████████████| 57 kB 1.5 MB/s
#      |████████████████████████████████| 56 kB 2.0 MB/s
# ...
# 100%|██████████| 1480/1480 [01:52<00:00, 13.10it/s]
# <selenium.webdriver.chrome.webdriver.WebDriver (session="74573a8b0cb8bbf6cfe78511c17ad477")>

# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/WeCloudData_Logo_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## My First Portfolio
# #### Farius Tjioesman August 8 2020
#
# Been a week of self studied preparing myself for September 21 classes and having fun learing Python, NumPy, Panda, simple data import/exports, visualization with Mathplotlib. It reminds me the good old days when I was obsessed to learn computer programming in mid 80s but PC was not very affordable that time. I ended up bought a fancy casio graphical calculator FX-7000G (https://en.wikipedia.org/wiki/Casio_fx-7000G).
#
# I have been leaving my old duty almost a month now. I remember that I sketched dozen CAD models every week to convey customer requirement from Manitoba to Newfoundland to pricing department for quotes and also for project clarification that require 2D/3D modeling and sometimes with finite element analysis, vector analysis to understand critical point of machine body that may be exposed to more forces, friction, heat or arc flashes.
#
# Inspired by my teenaged days and my skill using  drafting tools I am keen to apply few features of Mathplotlib to mimic WeCloudData logo curves with closest mathematical formulas. The color degradation was far from perfect as I did not apply the high-definition instead simplify the structure with less components to shorten the codes.
#
# I am  excited for transition in my career from old-fashion manufacturing/engineering into what I wished for when I was fifteen. Thanks to Amir, Maryam, Parry, Shaohua and  Sameer that inspired me lot in this data science program for the rest of the year.

# %% [markdown]
# ![wcdlogo.jpg](data:image/jpeg;base64,...)

# %%
import numpy as np; 
import matplotlib.lines as mlines; 
import matplotlib.pyplot as plt; 

fig = plt.figure(); 
plt.xlim(-6, 6), 
plt.ylim(-5, 3);

x = np.linspace(-1.3, 1.65, 50); plt.plot(x, (4-(x)**2)**0.5, color='purple', linewidth=5);               
x = np.linspace(-1.865, -5.529, 50);plt.plot(x, (4-(x+3.529)**2)**0.5, color='red', linewidth=5);            
x = np.linspace(-5.4, -5.529, 50);plt.plot(x, -(4-(x+3.529)**2)**0.5, color='red', linewidth=5);           
x = np.linspace(-5.4, -3.28, 50);plt.plot(x, 0.48*(x+4.422)**2-1.141, color='red', linewidth=5);          
x = np.linspace(-1.627, -3.511, 50);plt.plot(x, 0.48*(x+2.769)**2-3.056, color='red', linewidth=5);          
x = np.linspace(0, -2.719, 50);plt.plot(x, 0.29*(x+1.361)**2-4.181, color='purple', linewidth=5);       
x = np.linspace(0, 2.719, 50);plt.plot(x, 0.29*(x-1.141)**2-4.181, color='purple', linewidth=5);       
x = np.linspace(4.943, 5.529, 50);plt.plot(x, -(4-(x-3.529)**2)**0.5, color='blue', linewidth=5);         
x = np.linspace(3.529, 5.504, 50); plt.plot(x, -0.48*(x-4.659)**2+0.615, color='blue', linewidth=5);       
x = np.linspace(2.229, 5.529, 50); plt.plot(x, (4-(x-3.529)**2)**0.5, color='blue', linewidth=5)

plt.plot([-5.400,-2.719], [-0.707,-3.654], color='red', linewidth=5)
plt.plot([-1.313,-3.280], [1.505,-0.515], color='red', linewidth=5)
plt.plot([2.229,-1.627], [1.531,-2.431], color='purple', linewidth=5)
plt.plot([3.529,0.028], [0.042,-3.627], color='purple', linewidth=5)
plt.plot([5.002,2.568], [-1.353,-3.648], color='blue', linewidth=5)

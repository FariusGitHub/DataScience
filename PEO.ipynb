# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/PEO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Farius Tjioesman's P.Eng credential webscraped from PEO website
# !pip install kora -q
from kora.selenium import wd
import time

wd.get("https://www.peo.on.ca/index.php/directory")

try:
    wd.find_element_by_xpath("/html/body/div[2]/div/section/div/article/\
    div/div/div[3]/div/div/form/div/div[1]/div/div/label[1]").click()
    wd.find_element_by_xpath("/html/body/div[2]/div/section/div/article/\
    div/div/div[3]/div/div/form/div/div[2]/div/div/div[3]/input")\
      .send_keys('100163136')
    wd.find_element_by_xpath("/html/body/div[2]/div/section/div/article/\
      div/div/div[3]/div/div/form/div/div[4]/div/div/div/button").click()

except:
    wd.quit()

time.sleep(1)
wd.execute_script("window.scrollTo(0, 0)")
display(wd)
wd.execute_script("window.scrollTo(0, 1850)")
display(wd)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="93593faa31b347d01533bb81c92d843c")>
# <selenium.webdriver.chrome.webdriver.WebDriver (session="93593faa31b347d01533bb81c92d843c")>

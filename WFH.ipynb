# %% [markdown]
# <a href="https://colab.research.google.com/github/FariusGitHub/DataScience/blob/master/WFH.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 在家工作的数据科学家
#
# https://farius.s3.us-east-2.amazonaws.com/wcd/Farius_Tjioesman_Final_Project.pdf

# %%
# !pip install kora -q
from kora.selenium import wd
from selenium.webdriver.common.by import By
import time

prefix='/html/body/main/div/div/div/div[3]/div[2]/div'; 

wd.get("https://www.coursecompare.ca/courses/calgary/weclouddata/sql/")
wd.find_element(By.XPATH, "/html/body/header/div[2]/div/div[2]/div[2]/"\
                "div/div/div").click(); time.sleep(1)
display(wd)

for i in range(10):
  wd.find_element(By.XPATH, prefix + "[4]/button").click(); time.sleep(1)

wd.find_element(By.XPATH, prefix + "[7]/div[2]/button").click(); 
wd.find_element(By.XPATH, prefix + "[6]/div[2]/div[1]/p").click(); 

display(wd)
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="5e7fddd1bf7d2275a0cccadf7ceb53ac")>
# <selenium.webdriver.chrome.webdriver.WebDriver (session="5e7fddd1bf7d2275a0cccadf7ceb53ac")>
